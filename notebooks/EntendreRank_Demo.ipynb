# %% [markdown]
# # EntendreRank Demo\nEnd-to-end example: data collection → detection → ranking → (optional) playlist.

# %%
import os, pandas as pd
print('See README for CLI steps. Load resulting CSVs here for exploration.')
